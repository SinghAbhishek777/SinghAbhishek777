# %% [markdown]
# <a href="https://colab.research.google.com/github/SinghAbhishek777/SinghAbhishek777/blob/main/driverdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Aug  9 14:06:31 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/my\ Drive/mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link './mydrive': File exists
# ls: cannot access '/mydrive': No such file or directory

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15460, done.
# remote: Total 15460 (delta 0), reused 0 (delta 0), pack-reused 15460
# Receiving objects: 100% (15460/15460), 14.07 MiB | 8.68 MiB/s, done.
# Resolving deltas: 100% (10385/10385), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !cp cfg/yolov4-tiny.cfg cfg/mask.cfg

# %%
# !mkdir "/mydrive/yolov4"
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov4’: No such file or directory

# %%
# !echo $'safe driving\ texting-right\ talkingonthephone-right\ texting-left\ talkingonthephone-left\ operatingtheradio\ drinking\ reachingbehind\ hairandmakeup\ talkingtopassenger' > data/obj.names

# %%
# !echo -e 'classes= 10\ntrain = data/train.txt\nvalid = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov4/'> data/obj.data

# %%
# !mkdir data/obj

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-08-09 14:54:18--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  17.8MB/s    in 9.8s
#
# 2022-08-09 14:54:29 (15.8 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !apt install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive2')
# Out:
# Mounted at /content/gdrive2

# %%
 drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/yolov4/driverdata.zip -d data/obj
# Out:
# Archive:  /content/drive/MyDrive/yolov4/driverdata.zip
#    creating: data/obj/driverdata/
#    creating: data/obj/driverdata/images/
#   inflating: data/obj/driverdata/images/classes.txt
#   inflating: data/obj/driverdata/images/img_1.jpg
#   inflating: data/obj/driverdata/images/img_1.txt
#   inflating: data/obj/driverdata/images/img_10.jpg
#   inflating: data/obj/driverdata/images/img_10.txt
#   inflating: data/obj/driverdata/images/img_100.jpg
#   inflating: data/obj/driverdata/images/img_100.txt
#   inflating: data/obj/driverdata/images/img_1000.jpg
#   inflating: data/obj/driverdata/images/img_1000.txt
#   inflating: data/obj/driverdata/images/img_1001.jpg
#   inflating: data/obj/driverdata/images/img_1001.txt
#   inflating: data/obj/driverdata/images/img_1002.jpg
#   inflating: data/obj/driverdata/images/img_1002.txt
#   inflating: data/obj/driverdata/images/img_1003.jpg
#   inflating: data/obj/driverdata/images/img_1003.txt
# ...

# %%
import glob
images_list = glob.glob("data/obj/driverdata/images/*.jpg")
print(images_list)
# Out:
# ['data/obj/driverdata/images/img_705.jpg', 'data/obj/driverdata/images/img_429.jpg', 'data/obj/driverdata/images/img_1177.jpg', 'data/obj/driverdata/images/img_396.jpg', 'data/obj/driverdata/images/img_252.jpg', 'data/obj/driverdata/images/img_128.jpg', 'data/obj/driverdata/images/img_23.jpg', 'data/obj/driverdata/images/img_301.jpg', 'data/obj/driverdata/images/img_582.jpg', 'data/obj/driverdata/images/img_3.jpg', 'data/obj/driverdata/images/img_549.jpg', 'data/obj/driverdata/images/img_1249.jpg', 'data/obj/driverdata/images/img_85.jpg', 'data/obj/driverdata/images/img_805.jpg', 'data/obj/driverdata/images/img_793.jpg', 'data/obj/driverdata/images/img_923.jpg', 'data/obj/driverdata/images/img_768.jpg', 'data/obj/driverdata/images/img_167.jpg', 'data/obj/driverdata/images/img_534.jpg', 'data/obj/driverdata/images/img_314.jpg', 'data/obj/driverdata/images/img_1196.jpg', 'data/obj/driverdata/images/img_1105.jpg', 'data/obj/driverdata/images/img_359.jpg', 'data/obj/driverdata/images/img
# ...

# %%
file = open("data/train.txt", "w")
file.write("\n".join(images_list))
file.close()

# %%
# !./darknet detector train data/obj.data cfg/mask.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 3153, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.628291), count: 2, class_loss = 128.526901, iou_loss = 0.051697, total_loss = 128.578598
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 506.339691, iou_loss = 0.000000, total_loss = 506.339691
#  total_bbox = 3155, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.718792), count: 2, class_loss = 128.526718, iou_loss = 0.068817, total_loss = 128.595535
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 506.339691, iou_loss = 0.000000, total_loss = 506.339691
#  total_bbox = 3157, rewritten_bbox = 0.000000 %
# ...
